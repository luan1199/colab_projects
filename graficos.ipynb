# %% [markdown]
# <a href="https://colab.research.google.com/github/luan1199/colab_projects/blob/master/graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
dataset = open('/content/sample_data/california_housing_test.csv','r')         
x = []
y = []

for line in dataset:
  line = line.strip() #23,34\n = 23,34
  a,b,c,d,e,f,g,h,i = line.split(',')
  x.append(a)
  y.append(b)
dataset.close()

plt.plot(x,y)
plt.title('example')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
dataset = open('/content/sample_data/california_housing_test.csv','r')
x = []
y = []

for line in dataset:
  line = line.strip() #23,34\n = 23,34
  a,b,c,d,e,f,g,h,i = line.split(',')
  x.append(a)
  y.append(b)
dataset.close()

fig = plt.figure()
rect = fig.patch
rect.set_facecolor('#31312e')

plt.plot(x,y)
plt.title('example')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
